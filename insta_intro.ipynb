# %%
print("My Name is Mohit")
print("My Favourite App is Whatsapp")
# Out:
# My Name is Mohit
# My Favourite App is Whatsapp

# %%
print("Welcome To Data Science with Python!")
# Out:
# Welcome To Data Science with Python!
